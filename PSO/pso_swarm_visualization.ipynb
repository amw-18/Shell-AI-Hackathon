# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
swarm1 = np.array(pd.read_csv('opt_swarm_smart.csv'))
# swarm2 = np.array(pd.read_csv('oswarms/oswarm2.csv'))

# %%
for part in swarm1:
    part_xy = part.reshape((50,2))
    plt.scatter(part_xy[:,0], part_xy[:,1], alpha=0.1, c='blue')
# for part in swarm2:
#     part_xy = part.reshape((50,2))
#     plt.scatter(part_xy[:,0], part_xy[:,1], alpha=0.1, c='red')

# %%
fig, axs = plt.subplots(1, 7, sharey=True,figsize=(100,12))
# fig.
years = [7, 8, 9, 13, 14, 15, 17]
for i,y in enumerate(years):
    sol = pd.read_csv(f'C:/Users/awals/Downloads/Shell AI Hackathon/Trials/opt_swarm_ans1_{y}.csv')
    axs[i].scatter(sol.x, sol.y, c='blue', s=3000)

plt.show()

# %%
fig = plt.figure(figsize=(20,6))
ax = plt.gca()
ax.set_aspect(1)
years = [7, 8, 9, 13, 14, 15, 17]
for i,y in enumerate(years):
    sol = pd.read_csv(f'C:/Users/awals/Downloads/Shell AI Hackathon/Trials/opt_swarm_ans1_{y}.csv')
    ax.scatter(sol.x, sol.y, alpha=0.1, c='blue', s=900)

# sol = pd.read_csv('C:/Users/awals/Downloads/Shell AI Hackathon/Trials/opt_swarm_ans31_1.csv')
# ax.scatter(sol.x, sol.y, alpha=0.21,c='red')

plt.show()

# %%
# sol = pd.read_csv(f'C:/Users/awals/Downloads/Shell AI Hackathon/Trials/opt_swarm_ans1_9.csv')
# plt.scatter(sol.x, sol.y)
plt.figure(figsize=(20,6)) #fig 
ax = plt.gca() #get the axis handle
ax.set_aspect(1) #sets the height to width ratio to 1
sol = pd.read_csv(f'C:/Users/awals/Downloads/Shell AI Hackathon/Trials/opt_swarm_ans1_9.csv')
plt.scatter(sol.x, sol.y, marker='o', s=900)
plt.show()

# %%
a = np.linspace(0.0033, 1, 100)
c = [0.1]#np.linspace(0.01, 10, 100)
for val in c:
    b = (1 - np.power(a,val))
    plt.plot(a, b)

plt.show()

# %%
fig = plt.figure(figsize=(6, 6))
ax = plt.gca()
ax.set_aspect(1)
for i in range(49, 50):
    particle = pd.read_csv(f"C:/Users/awals/Downloads/Shell AI Hackathon/PSO/brute/{i}.csv")
    ax.scatter(particle.x, particle.y, c='blue', alpha=1, s=850)

plt.show()

# %%
first = pd.read_csv(f"C:/Users/awals/Downloads/Shell AI Hackathon/PSO/FINAL_BRUTE.csv")
second = pd.read_csv(f"C:/Users/awals/Downloads/Shell AI Hackathon/PSO/brute6/50_1.csv")
third = pd.read_csv(f"C:/Users/awals/Downloads/Shell AI Hackathon/PSO/brute6/50.csv")
fig = plt.figure(figsize=(6, 6))
ax = plt.gca()
ax.set_aspect(1)
for part in [first, second, third]:
    ax.scatter(part.x, part.y, c='blue', alpha=0.33)

plt.show()
