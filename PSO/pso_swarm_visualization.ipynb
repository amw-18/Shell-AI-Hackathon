# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
swarm1 = np.array(pd.read_csv('oswarms/oswarm0.csv'))
swarm2 = np.array(pd.read_csv('oswarms/oswarm2.csv'))

# %%
for part in swarm1:
    part_xy = part.reshape((50,2))
    plt.scatter(part_xy[:,0], part_xy[:,1], alpha=0.1, c='blue')
for part in swarm2:
    part_xy = part.reshape((50,2))
    plt.scatter(part_xy[:,0], part_xy[:,1], alpha=0.1, c='red')
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
fig, axs = plt.subplots(1, 6, sharey=True,figsize=(70,10))
# fig.
for i in range(6):
    sol = pd.read_csv(f'C:/Users/awals/Downloads/Shell AI Hackathon/Trials/opt_swarm_ans{i+11}.csv')
    axs[i].scatter(sol.x, sol.y, c='blue')

plt.show()
# Out:
# &lt;Figure size 5040x720 with 6 Axes&gt;

# %%
fig, ax = plt.subplots()
# fig.
for i in range(4):
    sol = pd.read_csv(f'C:/Users/awals/Downloads/Shell AI Hackathon/Trials/opt_swarm_ans{i+28}.csv')
    ax.scatter(sol.x, sol.y, alpha=0.2, c='blue')

sol = pd.read_csv('C:/Users/awals/Downloads/Shell AI Hackathon/Trials/opt_swarm_ans31_1.csv')
ax.scatter(sol.x, sol.y, alpha=1,c='red')

plt.show()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
a = np.linspace(0.0033, 1, 100)
c = np.linspace(0.01, 10, 100)
for val in c:
    b = (1 - np.power(a,val))
    plt.plot(a, b)

plt.show()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;
