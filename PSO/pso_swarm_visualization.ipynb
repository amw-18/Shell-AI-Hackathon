# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
swarm = np.array(pd.read_csv('oswarm0.csv'))
swarm
# Out:
# array([[3272.81317487, 1320.60199046, 1522.36722461, ...,  169.68098212,
#         3899.61962599,   89.91067917],
#        [2060.11522729, 2738.47922084, 2543.4584568 , ..., 3023.71893281,
#         1655.27570195,  147.55895743],
#        [ 120.40515736, 3270.64000366, 3218.78516711, ...,  350.25997589,
#         2744.82563172, 2838.24293697],
#        ...,
#        [1990.53806596, 1455.83340686, 3393.01275058, ..., 1981.74561586,
#          134.19923977, 1980.79028068],
#        [1530.48587278, 2989.44945442,  943.54228336, ..., 1484.97631774,
#         1343.48360933, 3520.3703671 ],
#        [3788.9703861 ,  593.58780294, 1644.04211575, ..., 3677.87246783,
#         2423.68613967, 1133.73401761]])

# %%
for part in swarm:
    part_xy = part.reshape((50,2))
    plt.scatter(part_xy[:,0], part_xy[:,1], alpha=0.2, c='blue')

plt.show()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;
