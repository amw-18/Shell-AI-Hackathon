# %%
import pyswarms as ps 
from pyswarms.utils.functions import single_obj as fx
import numpy as np 

# Set-up hyperparameters
options = {'c1': 1.49, 'c2': 1.49, 'w': 0}

# Call instance of LBestPSO with a neighbour-size of 3 determined by
# the L2 (p=2) distance.
optimizer = ps.single.global_best.GlobalBestPSO(n_particles=64, dimensions=2, ftol=1e-16,                                               ftol_iter=50, options=options, bounds=([-512]*2,[512]*2))

# Perform optimization
stats = optimizer.optimize(fx.eggholder, iters=1000)
# Out:
# 2020-10-02 15:49:32,095 - pyswarms.single.global_best - INFO - Optimize for 1000 iters with {&#39;c1&#39;: 1.49, &#39;c2&#39;: 1.49, &#39;w&#39;: 0}
# pyswarms.single.global_best:  45%|████▍     |448/1000, best_cost=-960
# 2020-10-02 15:49:33,255 - pyswarms.single.global_best - INFO - Optimization finished | best cost: -959.6378234636456, best pos: [511.99961154 404.1948382 ]

# %%
import matplotlib.pyplot as plt 
from pyswarms.utils.plotters import plot_cost_history
# %matplotlib inline
plot_cost_history(optimizer.cost_history)
# Out:
# &lt;matplotlib.axes._subplots.AxesSubplot at 0x22a93b94308&gt;
# &lt;Figure size 720x576 with 1 Axes&gt;

# %%
import multiprocessing
multiprocessing.cpu_count()
# Out:
# 12
